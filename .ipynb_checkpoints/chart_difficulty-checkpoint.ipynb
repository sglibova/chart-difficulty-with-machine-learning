# %% [markdown]
# # Modeling and Predicting Chart Difficulties with Machine Learning

# %% [markdown]
# ## Business Understanding
# ### Domain Introduction
# Stepmania is an open-source software designed to support many styles of rhythm
# game play, but one of its most widely-used formats is for 4-panel “dance games”
# (well-known “dance game” examples are Dance Dance Revolution and In The Groove,
# but these are specifically-licensed games by Konami and Roxor). The software was
# released in 2001 and has since been updated through version 5.3 - the concept behind
# this software is to allow players to play a “DDR-like” game with virtually boundless
# customizations, including custom charts (arrow patterns for songs).
#
# ### Business Problem
# The problem that I aim to solve is using exploratory data analysis and statistical learning
# to help establish a standardization for song chart difficulty ratings based on various
# features of the chart, for example BPM, duration, and quantity of technical elements.
#
# ### Motivation
# While there are many respectable step-artists with expertise in their domains, there has
# not been an official and standardized rating system for song difficulties - it is not
# uncommon to see players in conversation over whether a song should be “re-rated”
# due to various features of its chart. Creating a method of standardization will help
# examine which features are the most important in determining difficulty and help
# step-artists remove the intuitive/guesswork element from rating their own charts.
# The community of rhythm game players is surprisingly large and the amount of
# dedication that this community has poured into creating an open-source rendition of
# rhythm games is incredible. This software is free and is used for tournament play and
# for writing charts and is a staple to any outside-of-arcade dance game player, and is
# sometimes employed in small, local arcades as well.

# %% [markdown]
# ## A Brief Overview of StepMania and "Dance Games"

# %% [markdown]
# ### What's the point?
# It's a game and you move your feet really fast!

# %% [markdown]
# ### Data Acquisition

# %% [markdown]
# ### Chart Features

# %% [markdown]
# See [this link](data/feature_dictionary.txt) for a full explanation of each feature that was extracted from the song files.

# %% [markdown]
# ## Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
not_stam = pd.read_csv('data/not_stam.csv')
stam = pd.read_csv('data/stam.csv')

# %%
column_names = not_stam.columns

# %%
ordered_features = ['title', 'artist', 'song_seconds', 'step_count', 'measure_count', 'bpm_weighted_avg', 'bpm_max', 'bpm_min',\
                    'bpm_mode', 'bpm_change_count', 'song_nps', 'nps_per_measure_max', 'nps_per_measure_avg', 'nps_per_measure_median',\
                    'nps_per_measure_std', 'nps_per_measure_mode', 'jumps', 'hands', 'quads', 'holds', 'mines', 'rolls',\
                    'crossovers', 'footswitches', 'crossover_footswitches', 'jacks', 'invalid_crossovers', 'stop_count',\
                    'stream_total', 'stream_count', 'stream_size_max', 'stream_size_avg', 'stream_size_std', 'break_count',\
                    'break_size_max', 'break_size_avg', 'break_total', 'break_size_std', 'difficulty', 'rating']

# %%
not_stam_df = not_stam[ordered_features]
stam_df = stam[ordered_features]

# %%
#not_stam_df.isna().sum()

# %%
#stam_df.isna().sum()

# %%
#not_stam_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4906 entries, 0 to 4905
# Data columns (total 40 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   title                   4906 non-null   object
#  1   artist                  4906 non-null   object
#  2   song_seconds            4906 non-null   float64
#  3   step_count              4906 non-null   int64
#  4   measure_count           4906 non-null   int64
#  5   bpm_weighted_avg        4906 non-null   float64
#  6   bpm_max                 4906 non-null   float64
#  7   bpm_min                 4906 non-null   float64
#  8   bpm_mode                4906 non-null   float64
#  9   bpm_change_count        4906 non-null   int64
#  10  song_nps                4906 non-null   float64
#  11  nps_per_measure_max     4906 non-null   float64
#  12  nps_per_measure_avg     4906 non-null   float64
#  13  nps_per_measure_median  4906 non-null   float64
#  14  nps_per_measure_std     4906 non-null   float64
#  15  nps_per_measure_mode    4906 non-null   float64
#  16  jumps                   4906 non-null   int64
#  17  hands                   4906 non-null   int64
#  18  quads                   4906 non-null   int64
#  19  holds                   4906 non-null   int64
#  20  mines                   4906 non-null   int64
#  21  rolls                   4906 non-null   int64
#  22  crossovers              4906 non-null   int64
#  23  footswitches            4906 non-null   int64
#  24  crossover_footswitches  4906 non-null   int64
#  25  jacks                   4906 non-null   int64
#  26  invalid_crossovers      4906 non-null   int64
#  27  stop_count              4906 non-null   int64
#  28  stream_total            4906 non-null   int64
#  29  stream_count            1785 non-null   float64
#  30  stream_size_max         1785 non-null   float64
#  31  stream_size_avg         1785 non-null   float64
#  32  stream_size_std         1537 non-null   float64
#  33  break_count             1785 non-null   float64
#  34  break_size_max          1785 non-null   float64
#  35  break_size_avg          1785 non-null   float64
#  36  break_total             1785 non-null   float64
#  37  break_size_std          1785 non-null   float64
#  38  difficulty              4906 non-null   object
#  39  rating                  4906 non-null   int64
# dtypes: float64(20), int64(17), object(3)
# memory usage: 1.5+ MB

# %%
non_numeric_cols = ['title', 'artist', 'difficulty']
numeric_cols = list(not_stam_df.columns.drop(non_numeric_cols))

# %%
not_stam_df.describe()
# Out:
#        song_seconds    step_count  measure_count  bpm_weighted_avg  \
# count   4906.000000   4906.000000    4906.000000       4906.000000
# mean     134.249081    471.901753      76.422340        127.928605
# std       49.793699    410.382150      30.335847         92.118842
# min        4.500124      0.000000       5.000000      -1599.514601
# 25%      116.000000    215.250000      63.000000        120.370370
# 50%      126.792453    436.000000      72.000000        131.084768
# 75%      139.726562    646.000000      85.000000        153.920280
# max     1955.585592  12540.000000    1135.000000       2142.537313
#
#             bpm_max      bpm_min     bpm_mode  bpm_change_count     song_nps  \
# count  4.906000e+03  4906.000000  4906.000000       4906.000000  4906.000000
# mean   8.375089e+04   118.541825   141.629921          8.866898     3.580331
# std    2.858027e+06    43.852396    31.312730         34.372861     3.621860
# min    9.000000e+01  -160.000000    47.000000          0.000000     0.000000
# 25%    1.280000e+02    86.667000   125.999992          0.000000     1.676989
# 50%    1.500000e+02   127.000000   135.000000          0.000000     3.396318
# 75%    1.875000e+02   145.000000   157.000000          4.000000     5.006758
# max    1.000000e+08   300.000000   352.000000        639.000000   132.440785
#
#        nps_per_measure_max  ...  stream_count  stream_size_max  \
# count         4.906000e+03  ...   1785.000000      1785.000000
# mean          4.592803e+03  ...      5.772549         5.088515
# std           1.669429e+05  ...      5.316109         6.886818
# min           0.000000e+00  ...      1.000000         1.000000
# 25%           3.184375e+00  ...      2.000000         1.000000
# 50%           6.000000e+00  ...      5.000000         3.000000
# 75%           9.500000e+00  ...      8.000000         6.000000
# max           7.500000e+06  ...    140.000000        80.000000
#
#        stream_size_avg  stream_size_std  break_count  break_size_max  \
# count      1785.000000      1537.000000  1785.000000     1785.000000
# mean          2.606974         1.723493     6.749020       29.859384
# std           3.454551         2.637174     5.303542       16.475313
# min           1.000000         0.000000     2.000000        1.000000
# 25%           1.000000         0.000000     3.000000       18.000000
# 50%           1.500000         0.809040     6.000000       27.000000
# 75%           2.461538         2.160247     9.000000       39.000000
# max          46.500000        24.345431   141.000000      146.000000
#
#        break_size_avg  break_total  break_size_std       rating
# count     1785.000000  1785.000000     1785.000000  4906.000000
# mean        14.604608    65.805602       11.378421     7.921117
# std         11.149159    31.687936        9.256155    22.229626
# min          1.000000     3.000000        0.000000     1.000000
# 25%          6.371429    52.000000        5.402482     4.000000
# 50%         11.000000    62.000000        8.660254     8.000000
# 75%         19.500000    74.000000       14.302847    10.000000
# max         89.000000   891.000000       80.610173  1337.000000
#
# [8 rows x 37 columns]

# %%
not_stam_df.loc[not_stam_df['rating'] == 1337]
# Out:
#                                       title       artist  song_seconds  \
# 3822  YO SKRILL DROP THE *TRIBAL SCREAMING*  PISS SPEARS     98.638522
#
#       step_count  measure_count  bpm_weighted_avg  bpm_max  bpm_min  bpm_mode  \
# 3822         376             65        172.438626    295.0     71.0     145.0
#
#       bpm_change_count  ...  stream_size_max  stream_size_avg  \
# 3822                46  ...              NaN              NaN
#
#       stream_size_std  break_count  break_size_max  break_size_avg  \
# 3822              NaN          NaN             NaN             NaN
#
#       break_total  break_size_std  difficulty  rating
# 3822          NaN             NaN   Challenge    1337
#
# [1 rows x 40 columns]

# %% [markdown]
# lol ^

# %%
not_stam_df.describe()
# Out:
#        song_seconds    step_count  measure_count  bpm_weighted_avg  \
# count   4906.000000   4906.000000    4906.000000       4906.000000
# mean     134.249081    471.901753      76.422340        127.928605
# std       49.793699    410.382150      30.335847         92.118842
# min        4.500124      0.000000       5.000000      -1599.514601
# 25%      116.000000    215.250000      63.000000        120.370370
# 50%      126.792453    436.000000      72.000000        131.084768
# 75%      139.726562    646.000000      85.000000        153.920280
# max     1955.585592  12540.000000    1135.000000       2142.537313
#
#             bpm_max      bpm_min     bpm_mode  bpm_change_count     song_nps  \
# count  4.906000e+03  4906.000000  4906.000000       4906.000000  4906.000000
# mean   8.375089e+04   118.541825   141.629921          8.866898     3.580331
# std    2.858027e+06    43.852396    31.312730         34.372861     3.621860
# min    9.000000e+01  -160.000000    47.000000          0.000000     0.000000
# 25%    1.280000e+02    86.667000   125.999992          0.000000     1.676989
# 50%    1.500000e+02   127.000000   135.000000          0.000000     3.396318
# 75%    1.875000e+02   145.000000   157.000000          4.000000     5.006758
# max    1.000000e+08   300.000000   352.000000        639.000000   132.440785
#
#        nps_per_measure_max  ...  stream_count  stream_size_max  \
# count         4.906000e+03  ...   1785.000000      1785.000000
# mean          4.592803e+03  ...      5.772549         5.088515
# std           1.669429e+05  ...      5.316109         6.886818
# min           0.000000e+00  ...      1.000000         1.000000
# 25%           3.184375e+00  ...      2.000000         1.000000
# 50%           6.000000e+00  ...      5.000000         3.000000
# 75%           9.500000e+00  ...      8.000000         6.000000
# max           7.500000e+06  ...    140.000000        80.000000
#
#        stream_size_avg  stream_size_std  break_count  break_size_max  \
# count      1785.000000      1537.000000  1785.000000     1785.000000
# mean          2.606974         1.723493     6.749020       29.859384
# std           3.454551         2.637174     5.303542       16.475313
# min           1.000000         0.000000     2.000000        1.000000
# 25%           1.000000         0.000000     3.000000       18.000000
# 50%           1.500000         0.809040     6.000000       27.000000
# 75%           2.461538         2.160247     9.000000       39.000000
# max          46.500000        24.345431   141.000000      146.000000
#
#        break_size_avg  break_total  break_size_std       rating
# count     1785.000000  1785.000000     1785.000000  4906.000000
# mean        14.604608    65.805602       11.378421     7.921117
# std         11.149159    31.687936        9.256155    22.229626
# min          1.000000     3.000000        0.000000     1.000000
# 25%          6.371429    52.000000        5.402482     4.000000
# 50%         11.000000    62.000000        8.660254     8.000000
# 75%         19.500000    74.000000       14.302847    10.000000
# max         89.000000   891.000000       80.610173  1337.000000
#
# [8 rows x 37 columns]

# %%
stam_df.describe()
# Out:
#        song_seconds    step_count  measure_count  bpm_weighted_avg  \
# count   2770.000000   2770.000000    2770.000000       2770.000000
# mean     288.196452   2198.314440     207.038989         91.091827
# std      288.831116   3079.940978     215.940315       2063.107094
# min       61.286375     20.000000      31.000000     -54098.122537
# 25%      189.488441   1107.000000     122.000000        142.000000
# 50%      253.821990   1788.000000     186.500000        174.000000
# 75%      317.961783   2531.750000     234.000000        194.750000
# max     7089.862103  73602.000000    5059.000000       2897.960243
#
#             bpm_max      bpm_min     bpm_mode  bpm_change_count     song_nps  \
# count  2.770000e+03  2770.000000  2770.000000       2770.000000  2770.000000
# mean   7.400090e+03   165.813575   173.008687          2.147653     7.418832
# std    1.698133e+05    41.356698    35.475943         16.611320     2.883204
# min    7.600000e+01    10.000000    76.000000          0.000000     0.106967
# 25%    1.538757e+02   140.000000   146.000000          0.000000     5.698107
# 50%    1.740000e+02   174.000000   174.000000          0.000000     7.500594
# 75%    1.975000e+02   192.000000   195.000000          0.000000     9.265589
# max    4.000000e+06   320.000000   320.000000        623.000000    18.614390
#
#        nps_per_measure_max  ...  stream_count  stream_size_max  \
# count          2770.000000  ...   2417.000000      2417.000000
# mean            107.637810  ...      9.401738        31.070335
# std            5066.528471  ...     11.599535        54.631979
# min               0.525000  ...      1.000000         1.000000
# 25%               9.509121  ...      4.000000         8.000000
# 50%              11.666667  ...      7.000000        17.000000
# 75%              13.413333  ...     11.000000        34.000000
# max          266666.683333  ...    222.000000      2058.000000
#
#        stream_size_avg  stream_size_std  break_count  break_size_max  \
# count      2417.000000      2336.000000  2416.000000     2416.000000
# mean         15.483513        10.137283    10.387003       39.260762
# std          46.406398        13.442319    11.600156       28.957123
# min           1.000000         0.000000     2.000000        1.000000
# 25%           4.315789         2.802393     5.000000       20.000000
# 50%           9.000000         6.110101     8.000000       32.000000
# 75%          17.142857        12.447700    12.000000       49.000000
# max        2058.000000       189.787249   223.000000      236.000000
#
#        break_size_avg  break_total  break_size_std       rating
# count     2416.000000  2416.000000     2416.000000  2770.000000
# mean        15.758811   110.434603       13.860076    13.356679
# std         16.540195    76.565721       13.137642     4.427319
# min          0.500000     1.000000        0.000000     1.000000
# 25%          6.333333    60.000000        6.581868    11.000000
# 50%         10.816667    96.000000       10.675768    13.000000
# 75%         18.800000   146.000000       16.585660    16.000000
# max        136.000000  1038.000000      161.220346    28.000000
#
# [8 rows x 37 columns]

# %%
fig, ax = plt.subplots(figsize = (10, 8))
graph = sns.histplot(data = not_stam_df, x = 'rating', kde = True)
graph.set(xlim = (0, 25), ylim = (0, 700))
graph.set(title = "Non-Stamina Difficulty Distribution");

# %%
to_drop = not_stam_df.loc[not_stam_df['rating'] > 25].index

# %% [markdown]
# found them.

# %%
not_stam_df = not_stam_df.drop(to_drop)

# %%
fig, ax = plt.subplots(figsize = (10, 8))
graph = sns.histplot(data = stam_df, x = 'rating', kde = True)
graph.set(xlim = (0, 30), ylim = (0, 400))
graph.set(title = "Stamina Chart Difficulty Distribution");

# %%
fig, ax = plt.subplots(figsize = (10, 8))
graph = sns.histplot(data = not_stam_df, x = 'rating', kde = True)
graph.set(xlim = (0, 25), ylim = (0, 700))
graph.set(title = "Non-Stamina Difficulty Distribution - No Outliers");

# %% [markdown]
# ## Data Understanding

# %% [markdown]
# # First Simple Model

# %%
import warnings

from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import MissingIndicator, SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB,BernoulliNB
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import SVC, LinearSVC, NuSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, cross_val_score, cross_validate, GridSearchCV, RandomizedSearchCV
from sklearn.feature_selection import SelectFromModel
from sklearn.pipeline import Pipeline
from sklearn.metrics import plot_confusion_matrix, precision_score, recall_score, accuracy_score, f1_score, roc_curve, auc, classification_report, log_loss
from sklearn.dummy import DummyClassifier
from sklearn import svm

from xgboost import XGBClassifier

from statsmodels.graphics.mosaicplot import mosaic

warnings.filterwarnings('ignore')
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Iterative Model Building

# %% [markdown]
# # Final Model

# %% [markdown]
# # Data Explanation

# %% [markdown]
# # Summary / Conclusions

# %% [markdown]
# # Next Steps
